# %% [markdown]
# <a href="https://colab.research.google.com/github/SubhamMohanty187/Data-Science/blob/main/Bi_variate_%26_Multi_variate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset("titanic")
flights = sns.load_dataset("flights")
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 1. Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(data=tips,x='total_bill', y='tip', hue='sex', style='smoker', size='size')
plt.title('Scatterplot of Total Bill vs Tip')
plt.show()

# %% [markdown]
# ### 2. Bar Plot (Numerical - Categorical)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=titanic, x='pclass', y='age', hue='sex')
plt.title('Bar Plot of Age by Pclass')
plt.show()

# %% [markdown]
# The horizontal black rod like structure on top of the barplot represents the Confidence Interval (C.I.)

# %% [markdown]
# ### 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(data=titanic, x='age', y='sex', hue='survived')
plt.title('Box Plot of Age by Sex')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age by Sex')

# %% [markdown]
# ### 4. Distplot (Numerical - Categorical)

# %%
sns.distplot(x=titanic['age'])
# Out:
# <ipython-input-9-e7048a12af3a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=titanic['age'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=titanic['age'], kde=False)
# Out:
# <ipython-input-10-655ab7ed68bb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=titanic['age'], kde=False)
# <Axes: >

# %%
sns.distplot(x=titanic['age'], hist=False)
# Out:
# <ipython-input-11-18e8953cb949>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=titanic['age'], hist=False)
# <Axes: ylabel='Density'>

# %%
sns.distplot(titanic[titanic['survived']==0]['age'], hist=False)
sns.distplot(titanic[titanic['survived']==1]['age'], hist=False)
plt.title('Distribution of Age by Survival')
# Out:
# <ipython-input-12-730d391a37c2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['age'], hist=False)
# <ipython-input-12-730d391a37c2>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.displot(data=titanic, x='age', kind='kde', hue='survived')  # Using the new displot() function.
plt.title('Distribution of Age by Survival')
# Out:
# Text(0.5, 1.0, 'Distribution of Age by Survival')

# %% [markdown]
# ### 5. HeatMap (Categorical - Categorical)

# %%
pd.crosstab(titanic['pclass'], titanic['survived'])
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['pclass'], titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
(titanic.groupby(by='pclass')['survived'].mean())*100
# Out:
# pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64

# %%
(((titanic.groupby(by='pclass')['survived'].mean())*100).plot(kind='bar'))
# Out:
# <Axes: xlabel='pclass'>

# %% [markdown]
# ### 6. ClusterMap (Categorical - Categorical)

# %% [markdown]
# It shows the closeness between the values using dendograms to show a structure like the hierarchial structure.

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
pd.crosstab(titanic['parch'], titanic['survived'])
# Out:
# survived    0    1
# parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0

# %%
sns.clustermap(pd.crosstab(titanic['parch'], titanic['survived']))

# %% [markdown]
# ### 7. Pairplot

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.pairplot(data=iris, hue='species')

# %% [markdown]
# ### 8. Lineplot (Numerical - Numerical)

# %% [markdown]
# It basically used when the dataset is having changes over time i.e with respect to time the dataset is created.

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
newdf=flights.groupby(by='year')['passengers'].sum().reset_index()
newdf
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data=newdf, x='year', y='passengers')
plt.title('Total Passengers by Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers by Year')

# %% [markdown]
# Visualizing the above data set in heatmap.

# %%
flights.pivot_table(values='passengers', index='month', columns='year')
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers', index='month', columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers', index='month', columns='year'))
